# %%
#TASK 1: 

import pandas as pd
url="https://www.basketball-reference.com/leagues/NBA_2021_per_game.html"
df_ht=pd.read_html(url)
df=df_ht[0]
df
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0   3.7  ...  .509
# 1      2       Jaylen Adams  PG  24  MIL   7   0   2.6  0.1   1.1  ...   NaN
# 2      3       Steven Adams   C  27  NOP  58  58  27.7  3.3   5.3  ...  .444
# 3      4        Bam Adebayo   C  23  MIA  64  64  33.5  7.1  12.5  ...  .799
# 4      5  LaMarcus Aldridge   C  35  TOT  26  23  25.9  5.4  11.4  ...  .872
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 726  536       Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  ...  .833
# 727  537     Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  ...  .628
# 728  538         Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  ...  .886
# 729  539        Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  ...  .714
# 730  540        Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  ...  .789
#
# ...

# %%
"""Interpretation: table is extracted from the URL."""

# %%
df1=df[["G","MP","FG","PTS"]]
df1
# Out:
#         G    MP   FG   PTS
# 0    61.0  12.1  2.0   5.0
# 1     7.0   2.6  0.1   0.3
# 2    58.0  27.7  3.3   7.6
# 3    64.0  33.5  7.1  18.7
# 4    26.0  25.9  5.4  13.5
# ..    ...   ...  ...   ...
# 726  27.0  25.8  3.9  10.0
# 727  68.0  24.3  5.4  12.1
# 728  63.0  33.7  7.7  25.3
# 729  48.0  20.9  3.8   9.4
# 730  72.0  22.3  3.6   9.0
#
# [731 rows x 4 columns]

# %%
#Converting datatype and filling missing values.

df["G"]=pa.to_numeric(df["G"],errors="coerce")
df["MP"]=pa.to_numeric(df["MP"], errors="coerce")
df["FG"]=pa.to_numeric(df["FG"], errors="coerce")
df["PTS"]=pa.to_numeric(df["PTS"], errors="coerce")
df.dtypes

df.isnull().sum()
df.dropna(inplace=True)
df.isnull().sum()
df["G"].fillna(df["G"].mean(), inplace=True)
df["MP"].fillna(df["MP"].mean(), inplace=True)
df["FG"].fillna(df["FG"].mean(), inplace=True)
df["PTS"].fillna(df["PTS"].mean(), inplace=True)
df.describe()
# Out:
#                 G          MP          FG         PTS
# count  647.000000  647.000000  647.000000  647.000000
# mean    39.591963   20.352241    3.346059    9.124730
# std     20.329647    8.723955    2.254705    6.221197
# min      1.000000    2.000000    0.000000    0.400000
# 25%     22.000000   13.700000    1.650000    4.600000
# 50%     41.000000   20.100000    2.800000    7.500000
# 75%     58.000000   27.500000    4.500000   12.150000
# max     72.000000   37.600000   11.200000   32.000000

# %%
"""Interpretation: columns are extracted from the dataset and converted to their correct datatypes."""

# %%
#TASK 3(i): 

import matplotlib.pyplot as plt
import numpy as np

print("Mean of Games:", df["G"].mean())
print("Mean of Minutes Played:", df["MP"].mean())
print("Mean of Field Goals:", df["FG"].mean())
print("Mean of Points:", df["PTS"].mean())
print("\nMedian of Games:", df["G"].median())
print("Median of Minutes Played:", df["MP"].median())
print("Median of Field Goals:", df["FG"].median())
print("Median of Points:", df["PTS"].median())
print("\nKurtosis of Games:", df["G"].kurtosis())
print("Kurtosis of Minutes Played:", df["MP"].kurtosis())
print("Kurtosis of Field Goals:", df["FG"].kurtosis())
print("Kurtosis of Points:", df["PTS"].kurtosis())
# Out:
# Mean of Games: 39.5919629057187
# Mean of Minutes Played: 20.352241112828438
# Mean of Field Goals: 3.3460587326120557
# Mean of Points: 9.124729520865532
#
# Median of Games: 41.0
# Median of Minutes Played: 20.1
# Median of Field Goals: 2.8
# Median of Points: 7.5
#
# Kurtosis of Games: -1.2178345082391233
# Kurtosis of Minutes Played: -0.9608574542585675
# Kurtosis of Field Goals: 0.6065350402785632
# Kurtosis of Points: 0.9097605731468281

# %%
#TASK 3(ii):
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.subplot(2, 2, 1)
plt.boxplot(df["G"])
plt.title("Distribution of G")
plt.subplot(2, 2, 2)
plt.boxplot(df["MP"])
plt.title("Distribution of MP")
plt.subplot(2, 2, 3)
plt.boxplot(df["FG"])
plt.title("Distribution of FG")
plt.subplot(2, 2, 4)
plt.boxplot(df["PTS"])
plt.title("Distribution of PTS")
plt.tight_layout()
plt.show()

# %%
"""Interpretation: mean,median,kurtosis are calculated and presented box plot."""
